# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/raw/train.csv')
df.head()
# Out:
#          id  price_rub        mark      model     generation  \
# 0  16799418    2200000         Kia   Sportage  IV Рестайлинг
# 1  14261299     300000        Ford   Maverick            III
# 2  10850488    2600000  Volkswagen  Caravelle             T6
# 3  16407528     549000        Opel      Astra   H Рестайлинг
# 4  12695854     700000     Hyundai   Santa Fe              I
#
#        configuration           complectation                body_type  \
# 0  Внедорожник 5 дв.  Prestige Black Edition  пятидверный внедорожник
# 1  Внедорожник 5 дв.                     NaN  пятидверный внедорожник
# 2            Минивэн               Trendline                  минивэн
# 3              Седан                Essentia                    седан
# 4  Внедорожник 5 дв.                     NaN  пятидверный внедорожник
#
#          color  displacement  ... owners_count condition      custom  \
# 0       чёрный           2.4  ...            1   среднее  растаможен
# 1  серебристый           3.0  ...            4   среднее  растаможен
# 2       чёрный           2.0  ...            2   среднее  растаможен
# 3       чёрный           1.6  ...            4   среднее  растаможен
# 4      красный           2.7  ...            3   среднее  растаможен
#
#         pts seller_type                region       city  \
# 0  оригинал     частник   Вологодская область  Череповец
# 1  дубликат     частник    Краснодарский край       Сочи
# 2  оригинал     частник  Оренбургская область       Орск
# 3  дубликат     частник     Самарская область     Самара
# 4  оригинал     частник    Краснодарский край  Краснодар
#
#                          address  \
# 0  Россия, Вологодская область,
# 1               Теневой переулок
# 2                            NaN
# 3                            NaN
# 4                Адлерский район
#
#                                              options  \
# 0  ["airbag-curtain","park-assist-r","leather","b...
# 1                                                NaN
# 2  ["isofix","front-seats-heat","hcc","heated-was...
# 3  ["abs","airbag-driver","airbag-passenger","air...
# 4                                                NaN
#
#                                          description
# 0  Автомобиль в отличном состоянии, вложений ника...
# 1  Есть жизненные повреждения, автомобиль рабочий...
# 2  Автомобиль в отличном состоянии, все то пройде...
# 3  Продаю личный автомобиль в хорошем состоянии. ...
# 4  Пороги переваренные, грм новый, масла в двигат...
#
# [5 rows x 27 columns]

# %%
df['log_price'] = np.log1p(df['price_rub'])
df['bin_horse_power'] = pd.cut(df['horse_power'], bins=[0, 100, 200, 300, 400, np.inf], labels=['0-100', '100-200', '200-300', '300-400', '400+'])
df['car_age'] = 2026 - df['year']

# %%
df['owners_count'].value_counts()
# Out:
# owners_count
# 4    23567
# 3    19134
# 1    18299
# 2    17595
# 0     1414
# Name: count, dtype: int64

# %%
df.loc[(df['owners_count'] == 0) & (df['seller_type'] == 'компания'), 'pts'] = 'оригинал'

# %%
df[df['color'].isna()==True]
# Out:
#              id  price_rub           mark     model       generation  \
# 11231  10762226    1850000        Hyundai  Santa Fe    II Рестайлинг
# 42133  10684422    1750000     Lada (ВАЗ)     Vesta                I
# 52190  16639311     935000     Lada (ВАЗ)     Vesta                I
# 56471  13823774     990000           Audi        A4          IV (B8)
# 60620  10702159    4700000            Kia   Sorento               IV
# 72819  10641285    1600000  Mercedes-Benz     Citan         I (W415)
# 73530  10636948     490000  Mercedes-Benz   E-Класс  II (W210, S210)
#
#             configuration        complectation                body_type color  \
# 11231   Внедорожник 5 дв.                  NaN  пятидверный внедорожник   NaN
# 42133  Универсал 5 дв. SW                  NaN                универсал   NaN
# 52190               Седан     Luxe (2019-2021)                    седан   NaN
# 56471               Седан             Стандарт                    седан   NaN
# 60620   Внедорожник 5 дв.  Premium (2020-2021)  пятидверный внедорожник   NaN
# 72819          Компактвэн              109 CDI               компактвэн   NaN
# 73530               Седан                  NaN                    седан   NaN
#
#        displacement  ... condition      custom       pts seller_type  \
# 11231           2.4  ...   среднее  растаможен  дубликат     частник
# 42133           1.6  ...   среднее  растаможен  оригинал     частник
# 52190           1.6  ...   среднее  растаможен  оригинал     частник
# 56471           1.8  ...   среднее  растаможен  оригинал     частник
# 60620           2.5  ...   среднее  растаможен  оригинал     частник
# 72819           1.5  ...   среднее  растаможен  оригинал     частник
# 73530           2.2  ...   среднее  растаможен  оригинал     частник
#
#                       region         city                    address  \
# 11231  Новосибирская область  Новосибирск      Новосибирская область
# 42133          Пермский край    Соликамск                        NaN
# 52190    Республика Дагестан     Кизилюрт                        NaN
# 56471     Краснодарский край       Туапсе  Привокзальная площадь, 16
# 60620     Пензенская область        Пенза                        NaN
# 72819         Омская область         Омск          Центральный округ
# 73530     Ростовская область       Донецк                        NaN
#
#                                                  options  \
# 11231                                                NaN
# 42133                                                NaN
# 52190  ["esp","immo","multi-wheel","wheel-power","eng...
# 56471  ["airbag-driver","airbag-side","abs","wheel-po...
# 60620  ["19-inch-wheels","alloy-wheel-disks","panoram...
# 72819  ["wheel-power","wheel-configuration1","third-r...
# 73530                                                NaN
#
#                                              description  log_price
# 11231  Авто полностью в полном порядке. По кузову в и...  14.430697
# 42133  К продаже Лада Веста СВ в отличной комплектаци...  14.375127
# 52190  Продам хорошую весту,не битая НО ЕСТЬ ВЫТЯНУТЫ...  13.748303
# 56471  Машина в хорошем состоянии реальному покупател...  13.805461
# 60620                                                NaN  15.363073
# 72819  Мercedеs citan  Eдинственный в Омскe) Ухoженны...  14.285515
# 73530  Автомобиль в достойном, ухоженном состоянии, д...  13.102163
#
# [7 rows x 28 columns]

# %% [markdown]
# Напишем функцию, которая будет заполнять пропуска для цвета самым "модным" цветом для этой марки + модели

# %%
def fill_color_by_mode(df):
    color_mode = df.groupby(['mark', 'model'])['color'].agg(lambda x: x.mode().iloc[0] if not x.mode().empty else pd.NA)
    
    color_dict = color_mode.to_dict()
    
    def fill_color(row):
        if pd.isna(row['color']):
            return color_dict.get((row['mark'], row['model']), row['color'])
        return row['color']
    
    df['color'] = df.apply(fill_color, axis=1)
    return df

df = fill_color_by_mode(df)

# %% [markdown]
# Заметим, что для всех строк, где есть пропуска в признаке 'km_age' признак 'seller_type' - компания.

# %%
df[(df['km_age'].isna()==True) & (df['seller_type'] != 'компания')]
# Out:
# Empty DataFrame
# Columns: [id, price_rub, mark, model, generation, configuration, complectation, body_type, color, displacement, drive_type, engine_type, horse_power, transmission, wheel, km_age, year, owners_count, condition, custom, pts, seller_type, region, city, address, options, description, log_price]
# Index: []
#
# [0 rows x 28 columns]

# %%
df['km_age'] = df['km_age'].fillna(df.loc[df['seller_type'] != 'компания', 'km_age'].median())

# %%
df.loc[(df['pts'].isna()==True) & (df['seller_type'] == 'компания')]
# Out:
# Empty DataFrame
# Columns: [id, price_rub, mark, model, generation, configuration, complectation, body_type, color, displacement, drive_type, engine_type, horse_power, transmission, wheel, km_age, year, owners_count, condition, custom, pts, seller_type, region, city, address, options, description, log_price, bin_horse_power, car_age]
# Index: []
#
# [0 rows x 30 columns]

# %%
df.loc[df['pts'].isna() & (df['seller_type'] == 'частник'), 'pts'] = 'Неизвестно'

# %%
df.loc[df['generation'].isna(), ['mark', 'model']]
# Out:
#              mark         model
# 14         Nissan          Tino
# 23     Lada (ВАЗ)          2109
# 58         Nissan       Bassara
# 64     Great Wall      Wingle 7
# 65     Great Wall      Hover H5
# ...           ...           ...
# 80003         BAW        Ace M7
# 80005        Dadi       Shuttle
# 80006       Oting       Paladin
# 80007      Hudson  Deluxe Eight
# 80008      Arcfox       Alpha T
#
# [7869 rows x 2 columns]

# %% [markdown]
# Постараемся как то умно заполнить пропуски в признаке 'generation'. Возможно, найдутся такие строки, где марка+модель дадут нам информацию о 'generation'. Если же таких нет, то поставим 'Неизвестно'.

# %%
def fill_generation(df):
    gen_mode = df.groupby(['mark', 'model'])['generation'].agg(
        lambda x: x.mode().iloc[0] if not x.mode().empty else pd.NA
    )
    
    gen_dict = gen_mode.to_dict()
    
    def fill_gen(row):
        if pd.isna(row['generation']):
            mode_val = gen_dict.get((row['mark'], row['model']), pd.NA)
            return mode_val if pd.notna(mode_val) else 'Неизвестно'
        return row['generation']
    
    df['generation'] = df.apply(fill_gen, axis=1)
    return df
df = fill_generation(df)

# %%
df.columns
# Out:
# Index(['id', 'price_rub', 'mark', 'model', 'generation', 'configuration',
#        'complectation', 'body_type', 'color', 'displacement', 'drive_type',
#        'engine_type', 'horse_power', 'transmission', 'wheel', 'km_age', 'year',
#        'owners_count', 'condition', 'custom', 'pts', 'seller_type', 'region',
#        'city', 'address', 'options', 'description', 'log_price',
#        'bin_horse_power', 'car_age'],
#       dtype='object')

# %%
df.loc[(df['owners_count'] == 0)]
# Out:
#              id  price_rub        mark        model    generation  \
# 67     16514530     550000         BMW      5 серии      IV (E39)
# 164    16590933    1148000  Lada (ВАЗ)       Granta  I Рестайлинг
# 264    15022794    2449000         GAC          GS3           NaN
# 413    16541862   12300000       Lexus           RX             V
# 443    16349543    1443000  Lada (ВАЗ)  Niva Travel             I
# ...         ...        ...         ...          ...           ...
# 79920  16573772    5059000      Jaecoo           J8           NaN
# 79928  15091603    1000000      Nissan         Leaf  I (ZE0/AZE0)
# 79989  15145447   14900000      Rivian          R1S           NaN
# 79996  15946715    3100000    Qingling       Taga H           NaN
# 80000  16246226    4990000        Aito           M5             I
#
#               configuration           complectation                body_type  \
# 67          Универсал 5 дв.                     NaN                универсал
# 164                 Лифтбек              Comfort'24                  лифтбек
# 264       Внедорожник 5 дв.                      GS  пятидверный внедорожник
# 413       Внедорожник 5 дв.                  Luxury  пятидверный внедорожник
# 443       Внедорожник 5 дв.  Comfort'24 (2023-2024)  пятидверный внедорожник
# ...                     ...                     ...                      ...
# 79920     Внедорожник 5 дв.                 Supreme  пятидверный внедорожник
# 79928         Хэтчбек 5 дв.                     NaN      пятидверный хэтчбэк
# 79989     Внедорожник 5 дв.          Launch Edition  пятидверный внедорожник
# 79996  Пикап Двойная кабина                     NaN                    пикап
# 80000     Внедорожник 5 дв.                Ultimate  пятидверный внедорожник
#
#              color  displacement  ... condition      custom       pts  \
# 67          чёрный           2.5  ...   среднее  растаможен       NaN
# 164    серебристый           1.6  ...   среднее  растаможен  оригинал
# 264          синий           1.5  ...   среднее  растаможен  оригинал
# 413         чёрный           2.4  ...   среднее  растаможен  оригинал
# 443          белый           1.7  ...   среднее  растаможен  оригинал
# ...            ...           ...  ...       ...         ...       ...
# 79920  серебристый           2.0  ...   среднее  растаможен  оригинал
# 79928      голубой           0.0  ...   среднее  растаможен       NaN
# 79989      зелёный           0.0  ...   среднее  растаможен       NaN
# 79996  серебристый           3.0  ...   среднее  растаможен       NaN
# 80000       чёрный           1.5  ...   среднее  растаможен  оригинал
#
#       seller_type                                   region             city  \
# 67        частник  Санкт-Петербург и Ленинградская область  Санкт-Петербург
# 164      компания                           Алтайский край            Бийск
# 264      компания                     Владимирская область         Владимир
# 413      компания                    Новосибирская область      Новосибирск
# 443      компания                     Республика Татарстан        Азнакаево
# ...           ...                                      ...              ...
# 79920    компания                    Архангельская область      Архангельск
# 79928     частник                       Ростовская область           Донецк
# 79989     частник                           Омская область             Омск
# 79996     частник                          Республика Крым      Севастополь
# 80000    компания                        Красноярский край       Красноярск
#
#                         address  \
# 67     территория Троицкое Поле
# 164        Советская улица, 202
# 264        улица Куйбышева, 24М
# 413      Станционная улица, 101
# 443     улица Шайхутдинова, 12Б
# ...                         ...
# 79920   Московский проспект, 35
# 79928      проспект Мира, 44А/3
# 79989                       NaN
# 79996           Республика Крым
# 80000           улица 9 Мая, 2Г
#
#                                                  options  \
# 67                                                   NaN
# 164    ["airbag-driver","isofix","power-child-locks-r...
# 264    ["18-inch-wheels","reduce-spare-wheel","led-li...
# 413    ["airbag-curtain","airbag-driver","airbag-pass...
# 443    ["engine-proof","usb","15-inch-wheels","alloy-...
# ...                                                  ...
# 79920  ["dha","hcc","airbag-curtain","remote-engine-s...
# 79928                                                NaN
# 79989  ["driver-seat-updown","electro-window-front","...
# 79996                                                NaN
# 80000  ["hcc","collision-prevention-assist","asr","ai...
#
#                                              description  log_price
# 67     Машина снята с учета, на белорусских транзитах...  13.217675
# 164    Безопасность:  - Подушка безопасности водителя...  13.953533
# 264    Премиум автомобиль GAC от официального дилера ...  14.711191
# 413    Комплектация «Luxury»: • Антиблокировочная сис...  16.325110
# 443    Центральная акция "Автомобили по старым ценам ...  14.182236
# ...                                                  ...        ...
# 79920  Комплектация «Supreme»: • Антиблокировочная си...  15.436680
# 79928  Автомобиль доставлен в 2021 году из США в полн...  13.815512
# 79989  Добрый день!  Продам авто, в идеальном состоян...  16.516872
# 79996  автомобиль собран в Китае на заводе Qingling. ...  14.946913
# 80000  ☑️ Новый автомобиль, на гарантии, с НДС! Стоим...  15.422947
#
# [1414 rows x 28 columns]
